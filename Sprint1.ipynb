# %%
from web3 import Web3

# Conectarse a la red Ethereum (Rinkeby)
web3 = Web3(Web3.HTTPProvider('https://remix.ethereum.org/#lang=es&optimize=false&runs=200&evmVersion=null&version=soljson-v0.8.24+commit.e11b9ed9.js'))

# Dirección del contrato y ABI
contract_address = '0x1dF0Cb6F67e86CaeEA7D60D8DbF0462395cdC608'
contract_abi = [
    [
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "bool",
				"name": "newValue",
				"type": "bool"
			}
		],
		"name": "BoolDataUpdated",
		"type": "event"
	},
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "newValue",
				"type": "uint256"
			}
		],
		"name": "NumericDataUpdated",
		"type": "event"
	},
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "string",
				"name": "newText",
				"type": "string"
			}
		],
		"name": "TextDataUpdated",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "boolData",
		"outputs": [
			{
				"internalType": "bool",
				"name": "",
				"type": "bool"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getBoolData",
		"outputs": [
			{
				"internalType": "bool",
				"name": "",
				"type": "bool"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getNumericData",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTextData",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "numericData",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "bool",
				"name": "_value",
				"type": "bool"
			}
		],
		"name": "setBoolData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "_value",
				"type": "uint256"
			}
		],
		"name": "setNumericData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_value",
				"type": "string"
			}
		],
		"name": "setTextData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "textData",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]
]

# Crear una instancia del contrato
contract = web3.eth.contract(address=contract_address, abi=contract_abi)

# Llamar a las funciones para añadir y consultar datos
# Añadir datos numéricos
transaction_numeric = contract.functions.setNumericData(123).transact()
transaction_receipt_numeric = web3.eth.wait_for_transaction_receipt(transaction_numeric)

# Obtener datos numéricos
numeric_data = contract.functions.getNumericData().call()
print("Numeric Data:", numeric_data)

# Añadir datos de texto
transaction_text = contract.functions.setTextData("Hello, World!").transact()
transaction_receipt_text = web3.eth.wait_for_transaction_receipt(transaction_text)

# Obtener datos de texto
text_data = contract.functions.getTextData().call()
print("Text Data:", text_data)

# Añadir datos booleanos
transaction_bool = contract.functions.setBoolData(True).transact()
transaction_receipt_bool = web3.eth.wait_for_transaction_receipt(transaction_bool)

# Obtener datos booleanos
bool_data = contract.functions.getBoolData().call()
print("Bool Data:", bool_data)
